# %% [markdown]
# <a href="https://colab.research.google.com/github/eda-akkaya/PatikaDevVeriAnaliziFinalCase1/blob/main/VeriAnaliziFinalCase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Bağlam**
#
# Bu veri seti bir havayolu yolcu memnuniyeti anketini içermektedir.
# Memnun (veya memnun olmayan) yolcuyla yüksek korelasyona sahip faktörler nelerdir?
#
# Yolcu memnuniyetini tahmin edebilir misiniz?
#
#
#
#
# # **İçerik**
#
# **Gender (Cinsiyet):** Yolcuların cinsiyeti (Kadın, Erkek)
#
# **Customer Type (Müşteri Türü):** Müşteri tipi (Sadık müşteri, Sadık olmayan müşteri)
#
# **Age (Yaş):** Yolcuların gerçek yaşı
#
# **Type of Travel (Seyahat Türü):** Yolcuların seyahat amacı (Kişisel Seyahat, İş Seyahati)
#
# **Class (Sınıf):** Yolcuların uçaktaki seyahat sınıfı (Business, Ekonomi, Ekonomi Plus)
#
# **Flight Distance (Uçuş Mesafesi):** Bu yolculuğun uçuş mesafesi
#
# **Inflight wifi service (Uçuş içi WiFi hizmeti):** WiFi hizmetinden memnuniyet seviyesi (0: Uygulanamaz; 1-5 arası puan)
#
# **Departure/Arrival time convenient (Kalkış/Varış zamanının uygunluğu):** Memnuniyet seviyesi
#
# **Ease of Online booking (Online rezervasyon kolaylığı):** Memnuniyet seviyesi
#
# **Gate location (Kapı konumu):** Memnuniyet seviyesi
#
# **Food and drink (Yiyecek ve içecek):** Memnuniyet seviyesi
#
# **Online boarding (Online biniş):** Memnuniyet seviyesi
#
# **Seat comfort (Koltuk konforu):** Memnuniyet seviyesi
#
# **Inflight entertainment (Uçuş içi eğlence):** Memnuniyet seviyesi
#
# **On-board service (Uçuş içi servis):** Memnuniyet seviyesi
#
# **Leg room service (Bacak mesafesi servisi):** Memnuniyet seviyesi
#
# **Baggage handling (Bagaj işlemleri):** Memnuniyet seviyesi
#
# **Check-in service (Check-in servisi):** Memnuniyet seviyesi
#
# **Inflight service (Uçuş içi hizmet):** Memnuniyet seviyesi
#
# **Cleanliness (Temizlik):** Memnuniyet seviyesi
#
# **Departure Delay in Minutes (Kalkış gecikmesi - dakika):** Kalkışta gecikme süresi (dakika)
#
# **Arrival Delay in Minutes (Varış gecikmesi - dakika):** Varışta gecikme süresi (dakika)
#
# **Satisfaction (Memnuniyet):** Havayolu memnuniyet seviyesi (Memnuniyetli, nötr veya memnuniyetsiz)

# %% [markdown]
# Drive'dan veri setini çekme

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd

file_path = '/content/drive/MyDrive/AirlinePassengerSatisfaction/train.csv'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# # İstatistiksel Özet

# %%
df.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# # GPT ile istatistiklerin özeti ve yorumları

# %% [markdown]
# # İstatistiksel Özet Yorumları
#
# ## 1. Genel Bilgiler
# - Veri setinde **103.904** satır var.
# - **Arrival Delay in Minutes** değişkeninde **310 eksik değer** var (toplam 103.594 veri mevcut).
#
# ---
#
# ## 2. Sayısal Değişkenler Analizi
#
# | Değişken Adı          | Ortalama    | Minimum | Maksimum | Standart Sapma |
# |-----------------------|-------------|---------|----------|----------------|
# | Age                   | 39.4 yaş    | 7       | 85       | 15.1           |
# | Flight Distance       | 1189 km     | 31 km   | 4983 km  | 997 km         |
# | Departure Delay       | 14.8 dk     | 0 dk    | 1592 dk  | 38.2 dk        |
# | Arrival Delay         | 15.2 dk     | 0 dk    | 1584 dk  | 38.7 dk        |
#
# ### Yorumlar:
# - Yolcuların yaş ortalaması 39 yaş, en küçük yolcu 7 yaşında, en büyük yolcu 85 yaşında.
# - Uçuş mesafeleri çok değişken. Ortalama 1189 km, maksimum ise 4983 km (uzun mesafeler de var).
# - Gecikmelerde dikkat çeken bir durum var:
#   Ortalama kalkış gecikmesi 14.8 dk, fakat maksimum 1592 dakika (~26 saat!).
#   Bu değer bir aykırı değer olabilir, ileride analiz edilmesi gerekiyor.
# - Varış gecikmesinde de maksimum 1584 dakika (~26 saat!) gecikme bulunmakta.
#
# ---
#
# ## 3. Hizmet Puanları
#
# | Değişken Adı           | Ortalama Puan | Minimum | Maksimum |
# |------------------------|---------------|---------|----------|
# | Inflight wifi service   | 2.73          | 0       | 5        |
# | Food and drink         | 3.20          | 0       | 5        |
# | Seat comfort           | 3.44          | 0       | 5        |
# | Inflight entertainment | 3.36          | 0       | 5        |
# | Leg room service       | 3.38          | 0       | 5        |
# | Baggage handling       | 3.63          | 1       | 5        |
# | Check-in service       | 3.30          | 0       | 5        |
# | Cleanliness            | 3.64          | 0       | 5        |
#
# ###  Yorumlar:
# - Hizmet puanları genel olarak orta seviyede (ortalama yaklaşık 3 civarı).
# - **Baggage handling** ve **Cleanliness** hizmetleri en yüksek memnuniyet puanlarına sahip.
# - Bazı yolcular 0 puan vermiş; bu durum eksik hizmet ya da memnuniyetsizlik göstergesi olabilir (detaylı incelenmesi önerilir).
#
# ---
#
# ##  4. Dikkat Edilecekler
# - **Departure Delay in Minutes** ve **Arrival Delay in Minutes** değişkenlerinde yüksek sapmalar ve aşırı maksimum değerler var → Aykırı değer analizi yapılmalı.
# - **Arrival Delay in Minutes** değişkeninde eksik veri var → Eksik değer analizi yapılmalı.

# %% [markdown]
# Kategorik Değişkenler

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction'], dtype='object')

# %% [markdown]
# # Kategorik Değişkenlerin Dağılımı

# %%
categorical_columns = df.select_dtypes(include='object').columns

for col in categorical_columns:
    print(f"{col} Değişkeni:")
    print(df[col].value_counts())
    print("-" * 50)
# Out:
# Gender Değişkeni:
# Gender
# Female    52727
# Male      51177
# Name: count, dtype: int64
# --------------------------------------------------
# Customer Type Değişkeni:
# Customer Type
# Loyal Customer       84923
# disloyal Customer    18981
# Name: count, dtype: int64
# --------------------------------------------------
# Type of Travel Değişkeni:
# Type of Travel
# Business travel    71655
# Personal Travel    32249
# Name: count, dtype: int64
# --------------------------------------------------
# Class Değişkeni:
# Class
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: count, dtype: int64
# --------------------------------------------------
# satisfaction Değişkeni:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# # Eksik Değer Analizi

# %%
# Eksik değerlerin sayısını ve yüzdesini gösterelim
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100

# Sadece eksik değeri olan değişkenleri listeleyelim
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage})
missing_data = missing_data[missing_data['Missing Values'] > 0].sort_values(by='Percentage', ascending=False)

missing_data
# Out:
#                           Missing Values  Percentage
# Arrival Delay in Minutes             310    0.298352

# %% [markdown]
# Eksik verileri silme (oran çok küçük ve veri kaybı ihmal edilebilir).

# %%
# Eksik Arrival Delay in Minutes değerlerini içeren satırları silelim
df_cleaned = df.dropna(subset=['Arrival Delay in Minutes'])

# Temizlenen veri setinin boyutuna bakalım
print('Yeni veri seti boyutu:', df_cleaned.shape)
# Out:
# Yeni veri seti boyutu: (103594, 25)

# %% [markdown]
# # Aykırı Değer Analizi

# %%
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]

    print(f"{column} değişkeninde toplam {len(outliers)} aykırı değer var.")
    return outliers

# Örnek: Flight Distance için
outliers_flight_distance = detect_outliers(df_cleaned, 'Flight Distance')
outliers_departure_delay = detect_outliers(df_cleaned, 'Departure Delay in Minutes')
outliers_arrival_delay = detect_outliers(df_cleaned, 'Arrival Delay in Minutes')
# Out:
# Flight Distance değişkeninde toplam 2287 aykırı değer var.
# Departure Delay in Minutes değişkeninde toplam 14428 aykırı değer var.
# Arrival Delay in Minutes değişkeninde toplam 13954 aykırı değer var.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Flight Distance
plt.figure(figsize=(10,5))
sns.boxplot(x=df_cleaned['Flight Distance'])
plt.title('Flight Distance Aykırı Değer Analizi')
plt.show()

# Departure Delay
plt.figure(figsize=(10,5))
sns.boxplot(x=df_cleaned['Departure Delay in Minutes'])
plt.title('Departure Delay Aykırı Değer Analizi')
plt.show()

# Arrival Delay
plt.figure(figsize=(10,5))
sns.boxplot(x=df_cleaned['Arrival Delay in Minutes'])
plt.title('Arrival Delay Aykırı Değer Analizi')
plt.show()

# %% [markdown]
# Tüm Veriler İçin Aykırı Değer Kontrolü (IQR Yöntemi)

# %%
def detect_outliers_iqr(df):
    numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
    outlier_summary = {}

    for col in numeric_columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outlier_count = len(outliers)

        outlier_summary[col] = {
            'Outlier Count': outlier_count,
            'Lower Bound': lower_bound,
            'Upper Bound': upper_bound
        }

    return outlier_summary

# Fonksiyonu çalıştıralım
outlier_results = detect_outliers_iqr(df_cleaned)

# Sonuçları yazdıralım
for variable, result in outlier_results.items():
    print(f"{variable}: {result['Outlier Count']} aykırı değer.")
    print(f"Alt Sınır: {result['Lower Bound']}, Üst Sınır: {result['Upper Bound']}")
    print('-' * 50)
# Out:
# Unnamed: 0: 0 aykırı değer.
# Alt Sınır: -51986.5, Üst Sınır: 155871.5
# --------------------------------------------------
# id: 0 aykırı değer.
# Alt Sınır: -64650.125, Üst Sınır: 194582.875
# --------------------------------------------------
# Age: 0 aykırı değer.
# Alt Sınır: -9.0, Üst Sınır: 87.0
# --------------------------------------------------
# Flight Distance: 2287 aykırı değer.
# Alt Sınır: -1579.5, Üst Sınır: 3736.5
# --------------------------------------------------
# Inflight wifi service: 0 aykırı değer.
# Alt Sınır: -1.0, Üst Sınır: 7.0
# --------------------------------------------------
# Departure/Arrival time convenient: 0 aykırı değer.
# Alt Sınır: -1.0, Üst Sınır: 7.0
# --------------------------------------------------
# Ease of Online booking: 0 aykırı değer.
# Alt Sınır: -1.0, Üst Sınır: 7.0
# --------------------------------------------------
# Gate location: 0 aykırı değer.
# Alt Sınır: -1.0, Üst Sınır: 7.0
# ...

# %% [markdown]
# 1. Flight Distance
# Bu aykırılar büyük ihtimalle gerçek uzun uçuşlar.
#
# Silmek yerine olduğu gibi bırakmak mantıklı.
#
# 2. Checkin service
# Puan aralığı 0-5 olmalı.
#
# 5.5 üzerindeki değerler veri hatası olabilir.
#
# Bu aykırı değerleri 5 ile değiştirmek veya bu satırları silmek mantıklı.
#
# 3. Departure ve Arrival Delay
# Gecikme değerlerinde çok yüksek aykırılar var (1000+ dakika gibi).
#
# Bu veriler ya hatalı ya çok ekstrem.
#
# 30 dakika üzerindekileri aykırı olarak işaretleyip silebilir veya makul bir üst sınır koyabiliriz.

# %%
# Departure Delay, Arrival Delay ve Checkin service için aykırı değer sınırlarını belirleyip
# bu sınırların dışındaki satırları siliyoruz

df_cleaned = df_cleaned[
    (df_cleaned['Departure Delay in Minutes'] <= 30) &
    (df_cleaned['Arrival Delay in Minutes'] <= 32.5) &
    (df_cleaned['Checkin service'] <= 5)
]

print("Aykırı değerlerin temizlenmesinden sonra veri seti boyutu:", df_cleaned.shape)

# %% [markdown]
# # Görselleştirme

# %% [markdown]
# **Sayısal Değişken Dağılımı (Histogram)**
#
# Age, Flight Distance, Departure Delay in Minutes, Arrival Delay in Minutes

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numeric_cols = ['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']

plt.figure(figsize=(16,12))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df_cleaned[col], kde=True, bins=30, color='skyblue')
    plt.title(f"{col} Dağılımı")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Kategorik Değişkenlerin Frekans Grafikleri (Bar Plot)**
#
# Gender, Customer Type, Type of Travel, Class, satisfaction

# %%
categorical_cols = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']

plt.figure(figsize=(16,12))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(3, 2, i)
    sns.countplot(data=df_cleaned, x=col, palette='pastel')
    plt.title(f"{col} Dağılımı")
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-18-1222183076.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_cleaned, x=col, palette='pastel')
# /tmp/ipython-input-18-1222183076.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_cleaned, x=col, palette='pastel')
# /tmp/ipython-input-18-1222183076.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_cleaned, x=col, palette='pastel')
# /tmp/ipython-input-18-1222183076.py:6: FutureWarning:
#
# ...

# %% [markdown]
# **Memnuniyet Durumuna Göre Sayısal Değişkenler (Boxplot)**
#
# Flight Distance ve Age'in memnuniyet (satisfaction) durumuna göre dağılımı

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.boxplot(x='satisfaction', y='Flight Distance', data=df_cleaned)
plt.title('Memnuniyete Göre Uçuş Mesafesi')

plt.subplot(1,2,2)
sns.boxplot(x='satisfaction', y='Age', data=df_cleaned)
plt.title('Memnuniyete Göre Yaş')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **RAPOR**

# %% [markdown]
# # Veri Analizi Projesi: Airline Passenger Satisfaction
#
# ## 1. Veri Seti ve Amaç
# Bu proje, havayolu yolcularının memnuniyetini etkileyen faktörleri analiz etmek amacıyla **Airline Passenger Satisfaction** (https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction) veri seti üzerinde gerçekleştirilmiştir. Veri setinde yolcuların demografik bilgileri, uçuş detayları ve hizmete ilişkin değerlendirmeler bulunmaktadır.
#
# ---
#
# ## 2. İstatistiksel Özet
#
# ### Sayısal Değişkenler
# - **Yaş (Age):** Ortalama 39.4, minimum 7, maksimum 85. Yolcuların yaş dağılımı geniş bir aralıkta yer almaktadır.
# - **Uçuş Mesafesi (Flight Distance):** Ortalama 1189 km, minimum 31 km, maksimum 4983 km. Uçuş mesafeleri kısa ve uzun mesafeler olmak üzere çeşitlilik gösteriyor.
# - **Kalkış Gecikmesi (Departure Delay):** Ortalama 14.8 dakika, maksimum 1592 dakika. Yüksek maksimum değerler aykırı değer şüphesi yaratmaktadır.
# - **Varış Gecikmesi (Arrival Delay):** Ortalama 15.2 dakika, maksimum 1584 dakika. Benzer şekilde gecikme sürelerinde aşırı yüksek değerler gözlenmiştir.
# - Hizmet puanları (örn. Wi-Fi, Yemek, Temizlik) genellikle 0-5 aralığında olup ortalama 3 civarındadır. En yüksek puanlar temizlik ve bagaj hizmetinde gözlemlenmiştir.
#
# ### Kategorik Değişkenler
# - Cinsiyet, müşteri tipi, seyahat türü, uçuş sınıfı ve memnuniyet gibi kategorik değişkenlerin frekansları incelenmiştir (detaylar görselleştirmelerde yer almaktadır).
#
# ---
#
# ## 3. Eksik Değer Analizi
# - Sadece **Arrival Delay in Minutes** değişkeninde %0.3 oranında (310 kayıt) eksik veri bulunmuştur.
# - Eksik değerler az olduğu için bu kayıtlar veri setinden çıkarılmıştır.
#
# ---
#
# ## 4. Aykırı Değer Analizi
# - **Flight Distance:** 2.287 aykırı değer tespit edilmiştir ancak bu uzun mesafeli uçuşlar olabilir, bu nedenle veriden çıkarılmamıştır.
# - **Checkin Service:** 12.853 aykırı değer tespit edilmiş, puan aralığı 0-5 olması gerektiğinden 5’in üzerindeki değerler veri hatası olarak kabul edilip bu kayıtlar silinmiştir.
# - **Departure Delay & Arrival Delay:** Yüksek değerler (30 dakikadan uzun kalkış ve 32.5 dakikadan uzun varış gecikmesi) aykırı olarak kabul edilip ilgili kayıtlar veri setinden çıkarılmıştır.
#
# ---
#
# ## 5. Görselleştirme Bulguları
#
# ### Sayısal Değişken Dağılımları
# - Yaş ve uçuş mesafesi dağılımları normal ve beklenen aralıklarda.
# - Gecikmelerin dağılımı büyük çoğunlukta 0-30 dakika arası yoğunlaşmış.
#
# ### Kategorik Değişken Frekansları
# - Yolcuların cinsiyeti, seyahat sınıfı ve memnuniyet durumları dengeli dağılmıştır.
# - Müşteri tipi ve seyahat türü çeşitliliği gözlemlenmiştir.
#
# ### Memnuniyete Göre Dağılımlar
# - Memnun yolcular genellikle daha kısa uçuş mesafesine ve farklı yaş aralıklarına sahip.
# - Yaş ve uçuş mesafesi ile memnuniyet arasında gözle görülür bir ilişki gözlenmiştir.
#
# ---
#
# ## 6. Sonuç ve Öneriler
#
# - **Veri Kalitesi:** Eksik ve aykırı değerlerin temizlenmesi ile veri seti analiz için uygun hale getirilmiştir.
# - **Memnuniyet Analizi:** Yaş ve uçuş mesafesi gibi değişkenlerin yolcu memnuniyetini etkileyebileceği öngörülmüştür.
# - **Gecikmeler:** Kalkış ve varış gecikmelerinde belirgin aykırı değerler bulunduğu için bunların modellenmesi dikkatle yapılmalıdır.
# - **İleri Çalışmalar:** Makine öğrenmesi modelleri ile memnuniyet tahmini, hizmet iyileştirme önerileri ve segmentasyon analizleri yapılabilir.
#
# ---
